# %%
import pandas as pd

# %%
ls
# Out:
# Activities.md
# Data_Marketing_Customer_Analysis_Round2.csv
# Data_Marketing_Customer_Analysis_Round2.xlsx
# Lab_Customer_Analysis_Case_Study.md
# Lab_Pandas_Grouping_Data_Cleaning_Vehicles.ipynb
# Lab_Pandas_Round-1.ipynb
# Lab_Pandas_Round-2.ipynb
# Lab_Plotting.ipynb
# file1.csv
# file2.csv
# healthcare4all.ipynb
# mtcars.csv
# vehicles.csv
# vehicles.xlsx

# %%
df1 = pd.read_csv("file1.csv")

# %%
df2 = pd.read_csv("file2.csv")

# %%
df1.describe()
# Out:
#              Income  Monthly Premium Auto  Total Claim Amount
# count   1071.000000           1071.000000         1071.000000
# mean   39295.701214            193.234360          404.986909
# std    30469.427060           1601.190369          293.027260
# min        0.000000             61.000000            0.382107
# 25%    14072.000000             68.000000          202.157702
# 50%    36234.000000             83.000000          354.729129
# 75%    64631.000000            109.500000          532.800000
# max    99960.000000          35354.000000         2893.239678

# %%
df1.count()
# Out:
# Customer                     1071
# ST                           1071
# GENDER                        954
# Education                    1071
# Customer Lifetime Value      1068
# Income                       1071
# Monthly Premium Auto         1071
# Number of Open Complaints    1071
# Policy Type                  1071
# Vehicle Class                1071
# Total Claim Amount           1071
# dtype: int64

# %%
df2.describe()
# Out:
#              Income  Monthly Premium Auto  Total Claim Amount
# count    996.000000            996.000000          996.000000
# mean   39764.920683            143.347390          417.609099
# std    30203.714667            572.289901          271.928647
# min        0.000000             61.000000            1.687291
# 25%    16505.500000             68.000000          278.794307
# 50%    36533.000000             80.000000          350.400000
# 75%    63540.000000            107.000000          513.339366
# max    99981.000000           7575.000000         2201.327879

# %%
df2.count()
# Out:
# Customer                     996
# ST                           996
# GENDER                       991
# Education                    996
# Customer Lifetime Value      992
# Income                       996
# Monthly Premium Auto         996
# Number of Open Complaints    996
# Total Claim Amount           996
# Policy Type                  996
# Vehicle Class                996
# dtype: int64

# %%
### ALWAYS CHECK THE DATATYPES! ###
df1.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %%
df2.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                         int64
# Monthly Premium Auto           int64
# Number of Open Complaints     object
# Total Claim Amount           float64
# Policy Type                   object
# Vehicle Class                 object
# dtype: object

# %%
df1.size
# Out:
# 44088

# %%
df2.size
# Out:
# 10956

# %%
df1.info
# Out:
# <bound method DataFrame.info of      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2.info ### check the data types
# Out:
# <bound method DataFrame.info of     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
# ...

# %%
set(df1.columns) == set(df2.columns)
# Out:
# True

# %% [markdown]
# # Merging 2 files of data

# %%
df3 = pd.concat([df1, df2])
df3
# Out:
#     Customer          ST GENDER             Education Customer Lifetime Value  \
# 0    RB50392  Washington    NaN                Master                     NaN
# 1    QZ44356     Arizona      F              Bachelor              697953.59%
# 2    AI49188      Nevada      F              Bachelor             1288743.17%
# 3    WW63253  California      M              Bachelor              764586.18%
# 4    GA49547  Washington      M  High School or Below              536307.65%
# ..       ...         ...    ...                   ...                     ...
# 991  HV85198     Arizona      M                Master              847141.75%
# 992  BS91566     Arizona      F               College              543121.91%
# 993  IL40123      Nevada      F               College              568964.41%
# 994  MY32149  California      F                Master              368672.38%
# 995  SA91515  California      M              Bachelor              399258.39%
#
# ...

# %%
## axis = 0 // concate rowwise // 
## concating vs. joining (logical connection) vs. merging

df3 = pd.concat([df1, df2], axis = 0, ignore_index=True)
df3
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4999  HV85198     Arizona      M                Master
# 5000  BS91566     Arizona      F               College
# 5001  IL40123      Nevada      F               College
# 5002  MY32149  California      F                Master
# 5003  SA91515  California      M              Bachelor
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df3.shape
# Out:
# (5004, 11)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Standardize Header Names

# %%
df3.columns = df3.columns.astype("str")

# %%
df3.columns = df3.columns.str.title()
df3.head()
# Out:
#   Customer          St Gender             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number Of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %% [markdown]
# Delete the column "Costumer"

# %%
df3.drop(['Customer'], axis=1)
# Out:
#               St Gender             Education Customer Lifetime Value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 4999     Arizona      M                Master              847141.75%
# 5000     Arizona      F               College              543121.91%
# 5001      Nevada      F               College              568964.41%
# 5002  California      F                Master              368672.38%
# 5003  California      M              Bachelor              399258.39%
#
#        Income  Monthly Premium Auto Number Of Open Complaints     Policy Type  \
# ...

# %% [markdown]
# Check the datatypes

# %%
df3.dtypes
# Out:
# Customer                      object
# St                            object
# Gender                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number Of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object

# %% [markdown]
# Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of complaints

# %%
df3['Number of Open Complaints'] = pd.to_int(df3['Number of Open Complaints'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-c536d7f4cda5> in <module>
# ----> 1 df3['Number of Open Complaints'] = pd.to_int(df3['Number of Open Complaints'])
#
# /opt/anaconda3/envs/DA_new/lib/python3.9/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'to_int'

# %%
df3.Gender.value_counts()
# Out:
# F         984
# M         874
# Male       40
# female     30
# Femal      17
# Name: Gender, dtype: int64

# %%
df3.Gender.replace("Male","M", inplace=True) ### inplace=True affects the data nachhaltig

# %%
df3.Gender.value_counts()
# Out:
# F         984
# M         914
# female     30
# Femal      17
# Name: Gender, dtype: int64

# %%
df3.Gender.replace("Femal","F", inplace=True)

# %%
df3.Gender.replace("female","F", inplace=True)

# %%
df3.Gender.value_counts()
# Out:
# F    1031
# M     914
# Name: Gender, dtype: int64

# %% [markdown]
# Filtering data and Correcting typos:
# Filter the data in state and gender and standardize them

# %%
df3.isnull()
# Out:
#       Customer     St  Gender  Education  Customer Lifetime Value  Income  \
# 0        False  False    True      False                     True   False
# 1        False  False   False      False                    False   False
# 2        False  False   False      False                    False   False
# 3        False  False   False      False                    False   False
# 4        False  False   False      False                    False   False
# ...        ...    ...     ...        ...                      ...     ...
# 4999     False  False   False      False                    False   False
# 5000     False  False   False      False                    False   False
# 5001     False  False   False      False                    False   False
# 5002     False  False   False      False                    False   False
# 5003     False  False   False      False                    False   False
#
#       Monthly Premium Auto  Number Of Open Complaints  Policy Type  \
# ...

# %%
### NaN-values == float // Make sure to eliminate them

np.NaN == np.NaN ### should return FALSE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-7931a0e3657a> in <module>
#       1 ### NaN-values == float // Make sure to eliminate them
#       2
# ----> 3 np.NaN == np.NaN ### should return FALSE
#
# NameError: name 'np' is not defined

# %% [markdown]
# Removing duplicates

# %%
df3.drop_duplicates() ### sind das ganze identische Datensätze???
# Out:
#      Customer          St Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4999  HV85198     Arizona      M                Master
# 5000  BS91566     Arizona      F               College
# 5001  IL40123      Nevada      F               College
# 5002  MY32149  California      F                Master
# 5003  SA91515  California      M              Bachelor
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# Replacing null values – Replace missing values with means of the column (for numerical columns)

# %%
df3.fillna(value=mean).astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-793549b36468> in <module>
# ----> 1 df3.fillna(value=mean).astype(int)
#
# NameError: name 'mean' is not defined

# %%
mean_df3_CLV = df3['Customer Lifetime Value'].mean(axis = 1, skipna = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-5b3516d68f50> in <module>
# ----> 1 mean_df3_CLV = df3['Customer Lifetime Value'].mean(axis = 1, skipna = True)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# ...

# %% [markdown]
# Bucketing the data:
#
# Write a function to replace the column "State" to different zones.
#
# California = West Region, Oregon = North West, Washington = East, Arizona, Nevada = Central

# %%
df3.St.value_counts()
# Out:
# Oregon        623
# California    488
# Arizona       328
# Nevada        223
# Washington    181
# Cali          120
# AZ             74
# WA             30
# Name: St, dtype: int64

# %%
### groupby?

# %% [markdown]
# Standardizing the data:
#
# Use string functions to standardize the text data (lower case)
