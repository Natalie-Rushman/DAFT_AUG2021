# %% [markdown]
# # Visualizing the King County Properties 2014/15

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
property_df = pd.read_csv("Final-Data_MidTermProject_Real-State-Regression.csv")

# %%
property_plots_df.head()
# Out:
#    bedrooms  bathrooms  house_floors  kcgs_waterfront  kcgs_view  \
# 0         7          8             3                0          4
# 1         6          8             3                0          3
# 2         5          5             2                1          2
# 3         6          8             2                0          4
# 4         5          7             1                1          4
#
#    kcgs_condition  kcgs_grade  year_construction  year_renovation  zip_code  \
# 0               3          12               1999                0     98053
# 1               4          13               1910             1987     98102
# 2               3          11               1940             2001     98004
# 3               3          13               2001                0     98039
# 4               3          12               1983             2009     98040
#
#      price  m2_living  m2_lot
# 0  2280000       1258   28601
# 1  7700000       1120    2565
# ...

# %%
property_plots_df.shape
# Out:
# (21597, 13)

# %%
first_column_df = property_plots_df.iloc[: , 1:]

# %%
property_plots_df.drop(columns=property_plots_df.columns[0], 
        axis=1, 
        inplace=True)

# %%
property_plots_df.head()
# Out:
#    bedrooms  bathrooms  house_floors  kcgs_waterfront  kcgs_view  \
# 0         7          8             3                0          4
# 1         6          8             3                0          3
# 2         5          5             2                1          2
# 3         6          8             2                0          4
# 4         5          7             1                1          4
#
#    kcgs_condition  kcgs_grade  year_construction  year_renovation  zip_code  \
# 0               3          12               1999                0     98053
# 1               4          13               1910             1987     98102
# 2               3          11               1940             2001     98004
# 3               3          13               2001                0     98039
# 4               3          12               1983             2009     98040
#
#      price  m2_living  m2_lot
# 0  2280000       1258   28601
# 1  7700000       1120    2565
# ...

# %%
property_plots_df.to_csv('Final-Data_MidTermProject_Real-State-Regression.csv', encoding="utf-8")

# %%
1662524.1840/531762.3242
### houses with waterfront 3 times more expensive than without waterfront
# Out:
# 3.1264422249191

# %%
sns.displot(
    data=property_plots_df,
    x="price",
    kind="hist",
    aspect=1.4,
    log_scale=10,
    bins=20
)

# %%
column_grade = property_plots_df["kcgs_grade"]
column_condition = property_plots_df["kcgs_condition"]

correlation_cond_gr = column_grade.corr(column_condition)
print(correlation_cond_gr)
# Out:
# -0.14689580091008836

# %%
property_plots_df.corr()
# Out:
#                    bedrooms  bathrooms  house_floors  kcgs_waterfront  \
# bedrooms           1.000000   0.489683      0.184901        -0.006834
# bathrooms          0.489683   1.000000      0.470488         0.058125
# house_floors       0.184901   0.470488      1.000000         0.026055
# kcgs_waterfront   -0.006834   0.058125      0.026055         1.000000
# kcgs_view          0.080008   0.171973      0.031367         0.401971
# kcgs_condition     0.026496  -0.136804     -0.217122         0.016611
# kcgs_grade         0.356563   0.664937      0.412797         0.082888
# year_construction  0.155670   0.541670      0.368250        -0.026153
# year_renovation    0.018389   0.029256      0.019717         0.092873
# zip_code          -0.154092  -0.223569     -0.018821         0.030272
# price              0.308787   0.492517      0.257945         0.266398
# m2_living          0.578253   0.727588      0.329901         0.103883
# ...

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(property_plots_df.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':8}, pad=12)

plt.show()

# %%
# Most important factors to the pricing seems to be the size of the living space and the grading.

# %%
sns.pairplot(property_plots_df)

# %%
plt.show()

# %%
fig1, ax1 = plt.subplots()

ax1.set_title("Distributuin view")

sns.barplot(x = kcgs_view.index, y = kcgs_view)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-932dd1bb0f63> in <module>
#       3 ax1.set_title("Distributuin view")
#       4
# ----> 5 sns.barplot(x = kcgs_view.index, y = kcgs_view)
#
# NameError: name 'kcgs_view' is not defined

# %%
sns.displot(
    data=property_plots_df,
    x="kcgs_view",
    kind="hist",
    aspect=1.4,
    log_scale=10
)
# Out:
# /opt/anaconda3/envs/DA_new/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-96ca0fe13bfc> in <module>
# ----> 1 sns.displot(
#       2     data=property_plots_df,
#       3     x="kcgs_view",
#       4     kind="hist",
#       5     aspect=1.4,
#
# /opt/anaconda3/envs/DA_new/lib/python3.9/site-packages/seaborn/distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2272
#    2273             _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2274             p.plot_univariate_histogram(**hist_kws)
#    2275
# ...

# %%
plt.show()
